# %%
# !pip install ultralytics

# %%
from google.colab import files

# Upload do seu arquivo zip ou pastas com imagens e anotações
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b98142d4-6a40-4ead-b4ea-45636d3578fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b98142d4-6a40-4ead-b4ea-45636d3578fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# Caminho do arquivo zip
zip_file_path = '/content/animals and people.v1i.yolov8-obb.zip'
output_dir = '/content/animals_people_v8_dataset/'

# Cria o diretório de saída
os.makedirs(output_dir, exist_ok=True)

# Descompacta o arquivo
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_dir)

print(f"Arquivos descompactados em: {output_dir}")
# Out:
# Arquivos descompactados em: /content/animals_people_v8_dataset/

# %%
# Treinamento com YOLOv8
# !yolo task=detect mode=train model=yolov8n.pt data=/content/animals_people_v8_dataset/dataset.yaml epochs=50 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Testar o modelo com imagens novas
# !python val.py --weights /content/runs/train/exp/weights/best.pt --data /content/animals_people_v8_dataset/dataset.yaml --img 640
# Out:
# python3: can't open file '/content/val.py': [Errno 2] No such file or directory
